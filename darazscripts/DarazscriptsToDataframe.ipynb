# %%
import pandas as pd
import json
import csv
f = open("F:/Darazdata/darazcategories/darazcategories/Nokia/page1") 
data = f.read()
dt = data.split('listItems')
dt2= dt[1].split("breadcrumb")
dt2[0] = dt2[0][2:]
dt2[0] = dt2[0][:-2]
obj = json.loads(dt2[0])
df= pd.DataFrame(obj)
df.head()
# Out:
#                                                 name        nid  \
# 0  Nokia 2.1 5.5 Display 5.5 8MP 5MP 1GB RAM 8GB ...  142914929
# 1  Nokia 2.3 - 6.2 HD+ Display - 2GB RAM - 32GB R...  132534672
# 2  Nokia C1 - 5.45  Display - 1Gb Ram - 16Gb Rom ...  138544171
# 3       Na 110 2019 1.77'' - Smart Camera - Dual Sim  128515576
# 4  Nokia 2.2 - Black 5.7 HD+ display 3GB RAM - 32...  130824113
#
#                                                icons  \
# 0                                                 []
# 1  [{'domClass': 'freeShipping', 'text': 'FreeShi...
# 2                                                 []
# 3                                                 []
# 4  [{'domClass': 'freeShipping', 'text': 'FreeShi...
#
#                                             utLogMap  \
# 0  {'x_object_type': 'item', 'x_item_ids': '14291...
# 1  {'x_object_type': 'item', 'x_item_ids': '13253...
# 2  {'x_object_type': 'item', 'x_item_ids': '13854...
# 3  {'x_object_type': 'item', 'x_item_ids': '12851...
# 4  {'x_object_type': 'item', 'x_item_ids': '13082...
#
#                                           productUrl  \
# 0  //www.daraz.pk/products/nokia-21-55-display-55...
# 1  //www.daraz.pk/products/nokia-23-62-hd-display...
# 2  //www.daraz.pk/products/nokia-c1-545-display-1...
# 3  //www.daraz.pk/products/na-110-2019-177-smart-...
# 4  //www.daraz.pk/products/nokia-22-black-57-hd-d...
#
#                                                image     price promotionId  \
# 0  https://static-01.daraz.pk/p/5972b3ffbc03785bd...  12450.00        null
# 1  https://static-01.daraz.pk/p/7fd16f0e1eabab03c...  15499.00        null
# 2  https://static-01.daraz.pk/p/4d9b5c72e5427fa3e...   8949.00        null
# 3  https://static-01.daraz.pk/p/a7ead374c41e19276...   4000.00        null
# 4  https://static-01.daraz.pk/p/f6ae4d5549fd1da5e...  14499.00        null
#
#     priceShow ratingScore  ... categories  \
# 0  Rs. 12,450           0  ...     [2, 3]
# 1  Rs. 15,499           5  ...     [2, 3]
# 2   Rs. 8,949     4.86842  ...     [2, 3]
# 3   Rs. 4,000           5  ...     [2, 3]
# 4  Rs. 14,499     4.85714  ...     [2, 3]
#
#                                           clickTrace  \
# 0  query:;nid:142914929;src:LazadaMainSrp;rn:2013...
# 1  query:;nid:132534672;src:LazadaMainSrp;rn:2013...
# 2  query:;nid:138544171;src:LazadaMainSrp;rn:2013...
# 3  query:;nid:128515576;src:LazadaMainSrp;rn:2013...
# 4  query:;nid:130824113;src:LazadaMainSrp;rn:2013...
#
#                                        addToCartSkus     itemId       skuId  \
# 0  [{'sku': '142914929_PK-1303656250', 'skuId': '...  142914929  1303656250
# 1  [{'sku': '132534672_PK-1292750228', 'skuId': '...  132534672  1292750228
# 2  [{'sku': '138544171_PK-1298584373', 'skuId': '...  138544171  1298584373
# 3  [{'sku': '128515576_PK-1287665805', 'skuId': '...  128515576  1287665805
# 4  [{'sku': '130824113_PK-1295516042', 'skuId': '...  130824113  1295516042
#
#   inStock isAD originalPrice originalPriceShow discount
# 0    True    0           NaN               NaN      NaN
# 1    True    0           NaN               NaN      NaN
# 2    True    0           NaN               NaN      NaN
# 3    True    0           NaN               NaN      NaN
# 4    True    0           NaN               NaN      NaN
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (40, 35)
